# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhunisha1302/NLP/blob/main/Stopword_Removal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')

sentence = "She is cooking and cleaning the house"

# Tokenization
tokens = sentence.split()

# Lemmatization (treat words as verbs)
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word, 'v') for word in tokens]

print("Tokens:", tokens)
print("Lemmatized Words:", lemmatized_words)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Tokens: ['She', 'is', 'cooking', 'and', 'cleaning', 'the', 'house']
# Lemmatized Words: ['She', 'be', 'cook', 'and', 'clean', 'the', 'house']
